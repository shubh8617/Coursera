# %% [markdown]
# # Capstone project week 4 Peer Graded Assignment

# %% [markdown]
# ## Toronto the city for business and trade

# %% [markdown]
# ### Introduction to the Problem

# %% [markdown]
# #### About the city Toronto

# %% [markdown]
# Toronto is the provincial capital of Ontario and the most populous city in Canada, with a population of 2,731,571 in 2016. Current to 2016, the Toronto census metropolitan area (CMA), of which the majority is within the Greater Toronto Area (GTA), held a population of 5,928,040, making it Canada's most populous CMA. Toronto is the fastest growing city in North America, and is the anchor of an urban agglomeration, known as the Golden Horseshoe in Southern Ontario, located on the northwestern shore of Lake Ontario. Toronto is an international centre of business, finance, arts, and culture, and is recognized as one of the most multicultural and cosmopolitan cities in the world.

# %% [markdown]
# #### Business Plan

# %% [markdown]
# Toronto is a city of business and trade, a billionaire guy from India is coming to invest in some business in Toronto after seeing the potential of the city and the growth rate he becomes sure that Toronto is the right place to invest his money but the problem is that he is unsure in which field he want to invest money like in the field of restaurants, hotels, shopping complexes, cafes and many more. So he asks a team to look for all the fields mentioned above and give him an idea which field is good to invest the parameters for judging can be different just like if he looks for restaurants then it depends on where it is located how is the popularity of that restaurant the services provided to the customers if the response is good this will lead the businessman buying the restaurant and is same with other fields. We'll be using Foursquare API to analyze different fields such as restaurants, hotels, cafes, shopping complex and check out their neighbourhood in the city of Toronto and also the businessman is coming to take some good memories of canada back with him so he is coming with some professional photographers and it's an intended request of the businessman that it will be more preferable if the fields for which he is looking for is near some beautiful landscapes. So the main purpose is to make a list of places of landscape in Toronto, including the nearest restaurants, cafes, and shopping stores for each place.

# %% [markdown]
# #### Data Section

# %% [markdown]
# The data used in this project is provided by Foursquare location data. All the data of the restaurants,hotels,cafes are taken out with the help of Foursquare API. We will also use Foursquare location data to find the details of the neighbours of that particular region.

# %% [markdown]
# ### Implementing the above problem

# %% [markdown]
# #### Code Section

# %% [markdown]
# ##### Importing all the required libraries

# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print("Libraries imported !! ")
# Out:
# Collecting package metadata: done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - anaconda/linux-64::conda-build==3.17.8=py36_0
#   - anaconda/linux-64::grpcio==1.16.1=py36hf8bcb03_1
#   - anaconda/linux-64::keras==2.1.5=py36_0
#   - anaconda/linux-64::libarchive==3.3.3=h5d8350f_5
#   - anaconda/linux-64::python-libarchive-c==2.8=py36_6
#   - anaconda/linux-64::tensorboard==1.8.0=py36hf484d3e_0
#   - anaconda/linux-64::tensorflow==1.8.0=h57681fa_0
#   - anaconda/linux-64::tensorflow-base==1.8.0=py36h5f64886_0
#   - defaults/linux-64::anaconda==5.3.1=py37_0
#   - defaults/linux-64::astropy==3.0.4=py37h14c3975_0
#   - defaults/linux-64::bkcharts==0.2=py37_0
#   - defaults/linux-64::blaze==0.11.3=py37_0
#   - defaults/linux-64::bokeh==0.13.0=py37_0
#   - defaults/linux-64::bottleneck==1.2.1=py37h035aef0_1
#   - defaults/linux-64::dask==0.19.1=py37_0
#   - defaults/linux-64::datashape==0.5.4=py37_1
#   - defaults/linux-64::mkl-service==1.1.2=py37h90e4bf4_5
#   - defaults/linux-64::numba==0.39.0=py37h04863e7_0
#   - defaults/linux-64::numexpr==2.6.8=py37hd89afb7_0
#   - defaults/linux-64::odo==0.5.1=py37_0
#   - defaults/linux-64::pytables==3.4.4=py37ha205bf6_0
#   - defaults/linux-64::pytest-arraydiff==0.2=py37h39e3cac_0
#   - defaults/linux-64::pytest-astropy==0.4.0=py37_0
#   - defaults/linux-64::pytest-doctestplus==0.1.3=py37_0
#   - defaults/linux-64::pywavelets==1.0.0=py37hdd07704_0
#   - defaults/linux-64::scikit-image==0.14.0=py37hf484d3e_1
# done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.7.5                |           py36_0         3.0 MB  conda-forge
#     conda-package-handling-1.3.10|           py36_0         257 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     libarchive-3.3.3           |    hb44662c_1005         1.4 MB  conda-forge
#     libiconv-1.15              |    h516909a_1005         2.0 MB  conda-forge
#     libxml2-2.9.9              |       h13577e0_1         1.3 MB  conda-forge
#     python-libarchive-c-2.8    |        py36_1004          21 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         8.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   conda-package-han~ conda-forge/linux-64::conda-package-handling-1.3.10-py36_0
#   geographiclib      conda-forge/noarch::geographiclib-1.49-py_0
#   libiconv           conda-forge/linux-64::libiconv-1.15-h516909a_1005
#
# The following packages will be UPDATED:
#
#   conda                       anaconda::conda-4.6.14-py36_0 --> conda-forge::conda-4.7.5-py36_0
#   geopy              conda-forge/linux-64::geopy-1.11.0-py~ --> conda-forge/noarch::geopy-1.20.0-py_0
#   libarchive          anaconda::libarchive-3.3.3-h5d8350f_5 --> conda-forge::libarchive-3.3.3-hb44662c_1005
#   libxml2               pkgs/main::libxml2-2.9.8-h26e45fe_1 --> conda-forge::libxml2-2.9.9-h13577e0_1
#   python-libarchive~ anaconda::python-libarchive-c-2.8-py3~ --> conda-forge::python-libarchive-c-2.8-py36_1004
#
#
#
# Downloading and Extracting Packages
# conda-package-handli | 257 KB    | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# conda-4.7.5          | 3.0 MB    | ##################################### | 100%
# python-libarchive-c- | 21 KB     | ##################################### | 100%
# libiconv-1.15        | 2.0 MB    | ##################################### | 100%
# libxml2-2.9.9        | 1.3 MB    | ##################################### | 100%
# libarchive-3.3.3     | 1.4 MB    | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# WARNING conda.base.context:use_only_tar_bz2(632): Conda is constrained to only using the old .tar.bz2 file format because you have conda-build installed, and it is <3.18.3.  Update or remove conda-build to get smaller downloads and faster extractions.
# Collecting package metadata (repodata.json): done
# Solving environment: failed
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - anaconda/linux-64::grpcio==1.16.1=py36hf8bcb03_1 -> openssl[version='>=1.1.1,<1.1.2.0a0']
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/linux-64
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# Libraries imported !!

# %% [markdown]
# #### Entering the foursquare details to explore Toronto

# %%
ClIENT_ID = '4K3D2W4JJJU32CN2CS0GJCSDQR2UFSRAC0FKSEB0IKSE4QSA'# Foursquare ID
ClIENT_SECRET = 'JGHHEXLTN1UNXP14FV3TV3E2ZLZI31ZWNTU0YCJ5WOQSILN5' #  Foursquare Secret
VERSION = '20180604'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: 4K3D2W4JJJU32CN2CS0GJCSDQR2UFSRAC0FKSEB0IKSE4QSA
# Foursquare_Secret:JGHHEXLTN1UNXP14FV3TV3E2ZLZI31ZWNTU0YCJ5WOQSILN5

# %% [markdown]
# #### Finding Latitude and Longitude Values of city Toronto

# %%
city = 'Toronto'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print("Latitude=",latitude)
print("Longitude=",longitude)
# Out:
# Latitude= 43.653963
# Longitude= -79.387207

# %% [markdown]
# #### Finding hotel with the help of url using foursqure

# %%
search_query = 'Hotel'
radius = 500
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4K3D2W4JJJU32CN2CS0GJCSDQR2UFSRAC0FKSEB0IKSE4QSA&client_secret=JGHHEXLTN1UNXP14FV3TV3E2ZLZI31ZWNTU0YCJ5WOQSILN5&ll=43.653963,-79.387207&v=20180604&query=Hotel&radius=500&limit=30'

# %% [markdown]
# #### Sending GET request to find and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d21dd7c0d2be7002c320109'},
#  'response': {'venues': [{'id': '4ab2d511f964a5209b6c20e3',
#     'name': 'Sheraton Centre Toronto Hotel',
#     'location': {'address': '123 Queen Street West',
#      'crossStreet': 'at York St.',
#      'lat': 43.651129283252786,
#      'lng': -79.38382900313331,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651129283252786,
#        'lng': -79.38382900313331}],
#      'distance': 416,
#      'postalCode': 'M5H 2M9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['123 Queen Street West (at York St.)',
#       'Toronto ON M5H 2M9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '4b68aed1f964a520de862be3',
#     'name': 'The Rex Hotel Jazz & Blues Bar',
#     'location': {'address': '194 Queen St W',
#      'crossStreet': 'Queen & St. Patrick',
#      'lat': 43.65050475544005,
#      'lng': -79.38857723389897,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65050475544005,
#        'lng': -79.38857723389897}],
#      'distance': 400,
#      'postalCode': 'M5V 1Z1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['194 Queen St W (Queen & St. Patrick)',
#       'Toronto ON M5V 1Z1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e7931735',
#       'name': 'Jazz Club',
#       'pluralName': 'Jazz Clubs',
#       'shortName': 'Jazz Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '62225795'},
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '58b7d72dcc05d161570bd712',
#     'name': 'Sheraton Centre Toronto Hotel',
#     'location': {'address': '123 Queen Street West',
#      'lat': 43.65101646682632,
#      'lng': -79.38414798735793,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65101646682632,
#        'lng': -79.38414798735793}],
#      'distance': 410,
#      'postalCode': 'M5H 2M9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['123 Queen Street West',
#       'Toronto ON M5H 2M9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '402127087'},
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '52ce14b0498e50457ce11780',
#     'name': 'DoubleTree by Hilton Hotel Toronto Downtown',
#     'location': {'address': '108 Chestnut Street',
#      'crossStreet': 'Dundas St W',
#      'lat': 43.6546083,
#      'lng': -79.3859415,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6546083,
#        'lng': -79.3859415}],
#      'distance': 124,
#      'postalCode': 'M5G 1R3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['108 Chestnut Street (Dundas St W)',
#       'Toronto ON M5G 1R3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '4f343a31e4b0230a3b337a90',
#     'name': 'VFM Test Hotel',
#     'location': {'address': '123 Test Drive',
#      'crossStreet': 'at somewhere St',
#      'lat': 43.658434,
#      'lng': -79.387894,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658434,
#        'lng': -79.387894}],
#      'distance': 500,
#      'postalCode': 'M2M 2M2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['123 Test Drive (at somewhere St)',
#       'Toronto ON M2M 2M2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '5545d07e498e2facac03f666',
#     'name': 'Sheraton Centre Toronto Hotel - Grand Ballroom',
#     'location': {'address': '123 Queen Street West',
#      'crossStreet': 'at Bay Street',
#      'lat': 43.65119976208405,
#      'lng': -79.38452034718189,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65119976208405,
#        'lng': -79.38452034718189}],
#      'distance': 376,
#      'cc': 'CA',
#      'neighborhood': 'Financial District',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['123 Queen Street West (at Bay Street)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '56aa371be4b08b9a8d5734cf',
#       'name': 'Ballroom',
#       'pluralName': 'Ballrooms',
#       'shortName': 'Ballroom',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '4f53fb2ee4b036244bea152f',
#     'name': 'Stathcona Hotel',
#     'location': {'lat': 43.654947,
#      'lng': -79.386359,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654947,
#        'lng': -79.386359}],
#      'distance': 129,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '4a9d0a53f964a520d23720e3',
#     'name': 'Hilton Toronto',
#     'location': {'address': '145 Richmond St W',
#      'crossStreet': 'at University Ave',
#      'lat': 43.6501425,
#      'lng': -79.3854884,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6501425,
#        'lng': -79.3854884}],
#      'distance': 447,
#      'postalCode': 'M5H 2L2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['145 Richmond St W (at University Ave)',
#       'Toronto ON M5H 2L2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '4e31b74252b131dcebb08743',
#     'name': 'Shangri-La Toronto',
#     'location': {'address': '188 University Ave.',
#      'crossStreet': 'at Adelaide St. W',
#      'lat': 43.64912919417502,
#      'lng': -79.3865566853963,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64912919417502,
#        'lng': -79.3865566853963}],
#      'distance': 540,
#      'postalCode': 'M5H 0A3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['188 University Ave. (at Adelaide St. W)',
#       'Toronto ON M5H 0A3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '52a7186411d216bd254733b1',
#     'name': 'hilton hotel, richmondstreet E, 145,  toronto',
#     'location': {'address': 'Richmondstreet E, 145',
#      'lat': 43.6506246618514,
#      'lng': -79.3854884436715,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6506246618514,
#        'lng': -79.3854884436715}],
#      'distance': 396,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Richmondstreet E, 145', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d132951735',
#       'name': 'Hotel Pool',
#       'pluralName': 'Hotel Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '55de0cf9498e74d841ab26c1',
#     'name': '650 Hotel',
#     'location': {'address': '650 Bay Street',
#      'crossStreet': 'Elm Street',
#      'lat': 43.65704642307161,
#      'lng': -79.38441078793146,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65704642307161,
#        'lng': -79.38441078793146}],
#      'distance': 410,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['650 Bay Street (Elm Street)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '4be18ce28dd062b548533e3c',
#     'name': '89 Chestnut Residence',
#     'location': {'address': '89 Chestnut St.',
#      'crossStreet': 'at Armoury St.',
#      'lat': 43.654159528349275,
#      'lng': -79.38529050784362,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654159528349275,
#        'lng': -79.38529050784362}],
#      'distance': 155,
#      'postalCode': 'M5G 1R1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['89 Chestnut St. (at Armoury St.)',
#       'Toronto ON M5G 1R1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1a3941735',
#       'name': 'College Residence Hall',
#       'pluralName': 'College Residence Halls',
#       'shortName': 'Residence Hall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/residencehall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '53e3f70c498e8221abc0db4c',
#     'name': 'Be SixFifty Hotel',
#     'location': {'address': '650 Bay Street',
#      'crossStreet': 'Elm Street',
#      'lat': 43.65711975097656,
#      'lng': -79.38455963134766,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65711975097656,
#        'lng': -79.38455963134766}],
#      'distance': 411,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['650 Bay Street (Elm Street)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '4b0563c0f964a5200e5822e3',
#     'name': 'Marriott Downtown at CF Toronto Eaton Centre',
#     'location': {'address': '525 Bay Street',
#      'lat': 43.654728444284025,
#      'lng': -79.3824216350913,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654728444284025,
#        'lng': -79.3824216350913}],
#      'distance': 394,
#      'postalCode': 'M5G 2L2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['525 Bay Street', 'Toronto ON M5G 2L2', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '129932611'},
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '4e1632f31f6eb653a5e4aa66',
#     'name': 'Op mijn hotelkamer In Toronto',
#     'location': {'lat': 43.654235,
#      'lng': -79.386208,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654235,
#        'lng': -79.386208}],
#      'distance': 85,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '4ff8e46fe4b03705cefc7075',
#     'name': 'Fitness Centre',
#     'location': {'address': '525 Bay St.',
#      'crossStreet': 'in Marriott Downtown',
#      'lat': 43.654690455955546,
#      'lng': -79.3817385874303,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654690455955546,
#        'lng': -79.3817385874303}],
#      'distance': 447,
#      'postalCode': 'M5G 2L2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['525 Bay St. (in Marriott Downtown)',
#       'Toronto ON M5G 2L2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '53856fa411d2061fc84a3d0a',
#     'name': 'Lobby Lounge at the Shangri-La Toronto',
#     'location': {'address': '188 University Ave.',
#      'lat': 43.64915499986854,
#      'lng': -79.38654574367817,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64915499986854,
#        'lng': -79.38654574367817}],
#      'distance': 537,
#      'postalCode': 'M5H 0A3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['188 University Ave.',
#       'Toronto ON M5H 0A3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d121941735',
#       'name': 'Lounge',
#       'pluralName': 'Lounges',
#       'shortName': 'Lounge',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '4b5243a7f964a5209d7327e3',
#     'name': 'Fitness Centre',
#     'location': {'address': 'Sheraton Centre',
#      'crossStreet': '123 Queen St W',
#      'lat': 43.65098505166592,
#      'lng': -79.38400232084814,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65098505166592,
#        'lng': -79.38400232084814}],
#      'distance': 420,
#      'postalCode': 'M5H 2M9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Sheraton Centre (123 Queen St W)',
#       'Toronto ON M5H 2M9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '515e0d16e4b0e99f5f4764a8',
#     'name': 'Pool',
#     'location': {'address': 'Intercontinental',
#      'lat': 43.65097492328021,
#      'lng': -79.38405339932878,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65097492328021,
#        'lng': -79.38405339932878}],
#      'distance': 418,
#      'cc': 'CA',
#      'state': 'Ontario',
#      'country': 'Canada',
#      'formattedAddress': ['Intercontinental', 'Ontario', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d15e941735',
#       'name': 'Pool',
#       'pluralName': 'Pools',
#       'shortName': 'Pool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '4b0d95f7f964a520a14b23e3',
#     'name': 'Kumar For Men',
#     'location': {'address': 'Sheraton Centre',
#      'crossStreet': '123 Queen St W',
#      'lat': 43.65104394334362,
#      'lng': -79.38330173492432,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65104394334362,
#        'lng': -79.38330173492432}],
#      'distance': 452,
#      'postalCode': 'M5H 2M9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Sheraton Centre (123 Queen St W)',
#       'Toronto ON M5H 2M9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d106951735',
#       'name': "Men's Store",
#       'pluralName': "Men's Stores",
#       'shortName': "Men's Store",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_men_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '4b958a8ef964a5205ca834e3',
#     'name': 'Grand Ballroom',
#     'location': {'address': '123 Queen St. W',
#      'crossStreet': 'in Sheraton Centre',
#      'lat': 43.65121729803052,
#      'lng': -79.38377127936532,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65121729803052,
#        'lng': -79.38377127936532}],
#      'distance': 412,
#      'postalCode': 'M5H 2M9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['123 Queen St. W (in Sheraton Centre)',
#       'Toronto ON M5H 2M9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500476',
#     'hasPerk': False},
#    {'id': '4b99106ef964a520f95e35e3',
#     'name': 'Bistro on Two',
#     'location': {'address': '123 Queen St. W',
#      'crossStreet': 'at Sheraton Centre',
#      'lat': 43.651010971392715,
#      'lng': -79.38365752111193,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651010971392715,
#        'lng': -79.38365752111193}],
#      'distance': 435,
#      'postalCode': 'M5H 2M9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['123 Queen St. W (at Sheraton Centre)',
#       'Toronto ON M5H 2M9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500476',
#     'hasPerk': False}]}}

# %%
# assign all the relevent data from JSON to venues dataframe
venues = results['response']['venues']

# converting venues into dataframe 
dataframe_hotel = json_normalize(venues)
dataframe_hotel.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
#
#                          id       location.address location.cc location.city  \
# 0  4ab2d511f964a5209b6c20e3  123 Queen Street West          CA       Toronto
# 1  4b68aed1f964a520de862be3         194 Queen St W          CA       Toronto
# 2  58b7d72dcc05d161570bd712  123 Queen Street West          CA       Toronto
# 3  52ce14b0498e50457ce11780    108 Chestnut Street          CA       Toronto
# 4  4f343a31e4b0230a3b337a90         123 Test Drive          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada          at York St.                416
# 1           Canada  Queen & St. Patrick                400
# 2           Canada                  NaN                410
# 3           Canada          Dundas St W                124
# 4           Canada      at somewhere St                500
#
#                            location.formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2  [123 Queen Street West, Toronto ON M5H 2M9, Ca...
# 3  [108 Chestnut Street (Dundas St W), Toronto ON...
# 4  [123 Test Drive (at somewhere St), Toronto ON ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65112928325278...     43.651129
# 1  [{'label': 'display', 'lat': 43.65050475544005...     43.650505
# 2  [{'label': 'display', 'lat': 43.65101646682632...     43.651016
# 3  [{'label': 'display', 'lat': 43.6546083, 'lng'...     43.654608
# 4  [{'label': 'display', 'lat': 43.658434, 'lng':...     43.658434
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.383829                   NaN             M5H 2M9             ON
# 1    -79.388577                   NaN             M5V 1Z1             ON
# 2    -79.384148                   NaN             M5H 2M9             ON
# 3    -79.385942                   NaN             M5G 1R3             ON
# 4    -79.387894                   NaN             M2M 2M2             ON
#
#                                           name    referralId venuePage.id
# 0                Sheraton Centre Toronto Hotel  v-1562500476          NaN
# 1               The Rex Hotel Jazz & Blues Bar  v-1562500476     62225795
# 2                Sheraton Centre Toronto Hotel  v-1562500476    402127087
# 3  DoubleTree by Hilton Hotel Toronto Downtown  v-1562500476          NaN
# 4                               VFM Test Hotel  v-1562500476          NaN

# %% [markdown]
# #### Cleaning the hotel dataframe and showing hotels

# %%
# By cleaning I mean to inclue only the columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe_hotel.columns if col.startswith('location.')]+ ['id']
clean_dataframe_hotel = dataframe_hotel.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe_hotel['categories'] = clean_dataframe_hotel.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe_hotel.columns = [column.split('.')[-1] for column in clean_dataframe_hotel.columns]

clean_dataframe_hotel.head()
# Out:
#                                           name categories  \
# 0                Sheraton Centre Toronto Hotel      Hotel
# 1               The Rex Hotel Jazz & Blues Bar  Jazz Club
# 2                Sheraton Centre Toronto Hotel      Hotel
# 3  DoubleTree by Hilton Hotel Toronto Downtown      Hotel
# 4                               VFM Test Hotel      Hotel
#
#                  address  cc     city country          crossStreet  distance  \
# 0  123 Queen Street West  CA  Toronto  Canada          at York St.       416
# 1         194 Queen St W  CA  Toronto  Canada  Queen & St. Patrick       400
# 2  123 Queen Street West  CA  Toronto  Canada                  NaN       410
# 3    108 Chestnut Street  CA  Toronto  Canada          Dundas St W       124
# 4         123 Test Drive  CA  Toronto  Canada      at somewhere St       500
#
#                                     formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2  [123 Queen Street West, Toronto ON M5H 2M9, Ca...
# 3  [108 Chestnut Street (Dundas St W), Toronto ON...
# 4  [123 Test Drive (at somewhere St), Toronto ON ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65112928325278...  43.651129 -79.383829
# 1  [{'label': 'display', 'lat': 43.65050475544005...  43.650505 -79.388577
# 2  [{'label': 'display', 'lat': 43.65101646682632...  43.651016 -79.384148
# 3  [{'label': 'display', 'lat': 43.6546083, 'lng'...  43.654608 -79.385942
# 4  [{'label': 'display', 'lat': 43.658434, 'lng':...  43.658434 -79.387894
#
#   neighborhood postalCode state                        id
# 0          NaN    M5H 2M9    ON  4ab2d511f964a5209b6c20e3
# 1          NaN    M5V 1Z1    ON  4b68aed1f964a520de862be3
# 2          NaN    M5H 2M9    ON  58b7d72dcc05d161570bd712
# 3          NaN    M5G 1R3    ON  52ce14b0498e50457ce11780
# 4          NaN    M2M 2M2    ON  4f343a31e4b0230a3b337a90

# %% [markdown]
# #### Droping unnecessary columns from the dataframe

# %%
clean_dataframe2_hotel= clean_dataframe_hotel.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2_hotel
# Out:
#                                               name              categories  \
# 0                    Sheraton Centre Toronto Hotel                   Hotel
# 1                   The Rex Hotel Jazz & Blues Bar               Jazz Club
# 2                    Sheraton Centre Toronto Hotel                   Hotel
# 3      DoubleTree by Hilton Hotel Toronto Downtown                   Hotel
# 4                                   VFM Test Hotel                   Hotel
# 5   Sheraton Centre Toronto Hotel - Grand Ballroom                Ballroom
# 6                                  Stathcona Hotel                   Hotel
# 7                                   Hilton Toronto                   Hotel
# 8                               Shangri-La Toronto                   Hotel
# 9    hilton hotel, richmondstreet E, 145,  toronto              Hotel Pool
# 10                                       650 Hotel                   Hotel
# 11                           89 Chestnut Residence  College Residence Hall
# 12                               Be SixFifty Hotel                   Hotel
# 13    Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 14                   Op mijn hotelkamer In Toronto                   Hotel
# 15                                  Fitness Centre                     Gym
# 16          Lobby Lounge at the Shangri-La Toronto                  Lounge
# 17                                  Fitness Centre                     Gym
# 18                                            Pool                    Pool
# 19                                   Kumar For Men             Men's Store
# 20                                  Grand Ballroom             Event Space
# 21                                   Bistro on Two          Breakfast Spot
#
#                   address        lat        lng postalCode    state
# 0   123 Queen Street West  43.651129 -79.383829    M5H 2M9       ON
# 1          194 Queen St W  43.650505 -79.388577    M5V 1Z1       ON
# 2   123 Queen Street West  43.651016 -79.384148    M5H 2M9       ON
# 3     108 Chestnut Street  43.654608 -79.385942    M5G 1R3       ON
# 4          123 Test Drive  43.658434 -79.387894    M2M 2M2       ON
# 5   123 Queen Street West  43.651200 -79.384520        NaN       ON
# 6                     NaN  43.654947 -79.386359        NaN       ON
# 7       145 Richmond St W  43.650143 -79.385488    M5H 2L2       ON
# 8     188 University Ave.  43.649129 -79.386557    M5H 0A3       ON
# 9   Richmondstreet E, 145  43.650625 -79.385488        NaN       ON
# 10         650 Bay Street  43.657046 -79.384411        NaN       ON
# 11        89 Chestnut St.  43.654160 -79.385291    M5G 1R1       ON
# 12         650 Bay Street  43.657120 -79.384560        NaN       ON
# 13         525 Bay Street  43.654728 -79.382422    M5G 2L2       ON
# 14                    NaN  43.654235 -79.386208        NaN       ON
# 15            525 Bay St.  43.654690 -79.381739    M5G 2L2       ON
# 16    188 University Ave.  43.649155 -79.386546    M5H 0A3       ON
# 17        Sheraton Centre  43.650985 -79.384002    M5H 2M9       ON
# 18       Intercontinental  43.650975 -79.384053        NaN  Ontario
# 19        Sheraton Centre  43.651044 -79.383302    M5H 2M9       ON
# 20        123 Queen St. W  43.651217 -79.383771    M5H 2M9       ON
# 21        123 Queen St. W  43.651011 -79.383658    M5H 2M9       ON

# %% [markdown]
# #### Deleting rows with not assigned values

# %%
# delete rows with none values
clean_dataframe3 = clean_dataframe2_hotel.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                                             name              categories  \
# 0                  Sheraton Centre Toronto Hotel                   Hotel
# 1                 The Rex Hotel Jazz & Blues Bar               Jazz Club
# 2                  Sheraton Centre Toronto Hotel                   Hotel
# 3    DoubleTree by Hilton Hotel Toronto Downtown                   Hotel
# 4                                 VFM Test Hotel                   Hotel
# 7                                 Hilton Toronto                   Hotel
# 8                             Shangri-La Toronto                   Hotel
# 11                         89 Chestnut Residence  College Residence Hall
# 13  Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 15                                Fitness Centre                     Gym
# 16        Lobby Lounge at the Shangri-La Toronto                  Lounge
# 17                                Fitness Centre                     Gym
# 19                                 Kumar For Men             Men's Store
# 20                                Grand Ballroom             Event Space
# 21                                 Bistro on Two          Breakfast Spot
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651129 -79.383829    M5H 2M9    ON
# 1          194 Queen St W  43.650505 -79.388577    M5V 1Z1    ON
# 2   123 Queen Street West  43.651016 -79.384148    M5H 2M9    ON
# 3     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 4          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 7       145 Richmond St W  43.650143 -79.385488    M5H 2L2    ON
# 8     188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 11        89 Chestnut St.  43.654160 -79.385291    M5G 1R1    ON
# 13         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 15            525 Bay St.  43.654690 -79.381739    M5G 2L2    ON
# 16    188 University Ave.  43.649155 -79.386546    M5H 0A3    ON
# 17        Sheraton Centre  43.650985 -79.384002    M5H 2M9    ON
# 19        Sheraton Centre  43.651044 -79.383302    M5H 2M9    ON
# 20        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON
# 21        123 Queen St. W  43.651011 -79.383658    M5H 2M9    ON

# %%
array_1= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array_1)]
hotel_dataframe
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 2                  Sheraton Centre Toronto Hotel        Hotel
# 3    DoubleTree by Hilton Hotel Toronto Downtown        Hotel
# 4                                 VFM Test Hotel        Hotel
# 7                                 Hilton Toronto        Hotel
# 8                             Shangri-La Toronto        Hotel
# 13  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 20                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651129 -79.383829    M5H 2M9    ON
# 2   123 Queen Street West  43.651016 -79.384148    M5H 2M9    ON
# 3     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 4          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 7       145 Richmond St W  43.650143 -79.385488    M5H 2L2    ON
# 8     188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 13         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 20        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %% [markdown]
# #### Deleting hotels with duplicate hotel names

# %%
df_hotels_1 = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels_1
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 3    DoubleTree by Hilton Hotel Toronto Downtown        Hotel
# 4                                 VFM Test Hotel        Hotel
# 7                                 Hilton Toronto        Hotel
# 8                             Shangri-La Toronto        Hotel
# 13  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 20                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651129 -79.383829    M5H 2M9    ON
# 3     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 4          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 7       145 Richmond St W  43.650143 -79.385488    M5H 2L2    ON
# 8     188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 13         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 20        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# choose the hotel which has the same postalCode where the businessman is staying (Postal COde)
df_hotel = df_hotels_1[df_hotels_1.postalCode == 'M5H 2M9']
df_hotel
# Out:
#                              name   categories                address  \
# 0   Sheraton Centre Toronto Hotel        Hotel  123 Queen Street West
# 20                 Grand Ballroom  Event Space        123 Queen St. W
#
#           lat        lng postalCode state
# 0   43.651129 -79.383829    M5H 2M9    ON
# 20  43.651217 -79.383771    M5H 2M9    ON

# %% [markdown]
# #### Searching for parks to set a business

# %%
# search for Parks
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4K3D2W4JJJU32CN2CS0GJCSDQR2UFSRAC0FKSEB0IKSE4QSA&client_secret=JGHHEXLTN1UNXP14FV3TV3E2ZLZI31ZWNTU0YCJ5WOQSILN5&ll=43.653963,-79.387207&v=20180604&query=Park&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
park_results = requests.get(url).json()
park_results
# Out:
# {'meta': {'code': 200, 'requestId': '5d21deb25d891b002cccd1f4'},
#  'response': {'venues': [{'id': '4b170e47f964a5208cc123e3',
#     'name': "Queen's Park Subway Station",
#     'location': {'address': '691 University Ave',
#      'crossStreet': 'at College St',
#      'lat': 43.660006357009195,
#      'lng': -79.39027220226043,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.660006357009195,
#        'lng': -79.39027220226043}],
#      'distance': 716,
#      'postalCode': 'M5G 2P1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['691 University Ave (at College St)',
#       'Toronto ON M5G 2P1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fd931735',
#       'name': 'Metro Station',
#       'pluralName': 'Metro Stations',
#       'shortName': 'Metro',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4b54deadf964a520a3d027e3',
#     'name': 'Grange Park',
#     'location': {'lat': 43.652487552998565,
#      'lng': -79.39205307540142,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652487552998565,
#        'lng': -79.39205307540142}],
#      'distance': 423,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['btwn College, University, Queen & Spadina',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4ad4c05ef964a520bdf620e3',
#     'name': 'Trinity Bellwoods Park',
#     'location': {'address': '1053 Dundas St. W.',
#      'crossStreet': 'at Gore Vale Ave.',
#      'lat': 43.64707192840234,
#      'lng': -79.4137559260075,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64707192840234,
#        'lng': -79.4137559260075}],
#      'distance': 2271,
#      'postalCode': 'M5H 2N2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1053 Dundas St. W. (at Gore Vale Ave.)',
#       'Toronto ON M5H 2N2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4ad80fcef964a520a61021e3',
#     'name': 'One Park Lane',
#     'location': {'address': '280 Simcoe St',
#      'crossStreet': 'Dundas Street West',
#      'lat': 43.65544241747622,
#      'lng': -79.39005622787515,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65544241747622,
#        'lng': -79.39005622787515}],
#      'distance': 282,
#      'postalCode': 'M5T 2Y5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['280 Simcoe St (Dundas Street West)',
#       'Toronto ON M5T 2Y5',
#       'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4bb3c91a2397b7134d9f38b3',
#     'name': 'Clarence Square Park',
#     'location': {'address': 'Spadina Ave',
#      'crossStreet': 'at Wellington St W',
#      'lat': 43.64422227794523,
#      'lng': -79.3942301870698,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64422227794523,
#        'lng': -79.3942301870698}],
#      'distance': 1223,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Spadina Ave (at Wellington St W)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '59ddd7469ba3e51a75459568',
#     'name': 'Crunch Fitness - College Park',
#     'location': {'address': '382 Yonge Street',
#      'lat': 43.6592634,
#      'lng': -79.3826319,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6592634,
#        'lng': -79.3826319}],
#      'distance': 695,
#      'postalCode': 'M5G 1S8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['382 Yonge Street', 'Toronto ON M5G 1S8', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '532736199'},
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4bb79860cf2fc9b616779e02',
#     'name': 'Berczy Park',
#     'location': {'address': '35 Wellington St. East',
#      'lat': 43.64804835388851,
#      'lng': -79.3751722909452,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64804835388851,
#        'lng': -79.3751722909452}],
#      'distance': 1171,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['35 Wellington St. East', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4bfc5019da7120a132df49fd',
#     'name': 'St. Andrews Playground / Dog Park',
#     'location': {'address': '450 Adelaide Street West',
#      'crossStreet': 'Brant St & Adelaide St W',
#      'lat': 43.64738759338116,
#      'lng': -79.39875217247466,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64738759338116,
#        'lng': -79.39875217247466}],
#      'distance': 1183,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['450 Adelaide Street West (Brant St & Adelaide St W)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4b9d206bf964a520e69136e3',
#     'name': "Queen's Park",
#     'location': {'address': 'University Ave.',
#      'crossStreet': 'at Wellesley Ave.',
#      'lat': 43.66394609897775,
#      'lng': -79.39217952520835,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66394609897775,
#        'lng': -79.39217952520835}],
#      'distance': 1181,
#      'postalCode': 'M5R 2E8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['University Ave. (at Wellesley Ave.)',
#       'Toronto ON M5R 2E8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4b797b48f964a520c6fb2ee3',
#     'name': 'Bellevue Square Park',
#     'location': {'address': 'btwn Bellevue & Augusta Ave.',
#      'lat': 43.653610211432564,
#      'lng': -79.40219872192313,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653610211432564,
#        'lng': -79.40219872192313}],
#      'distance': 1208,
#      'postalCode': 'M5T 2N4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['btwn Bellevue & Augusta Ave.',
#       'Toronto ON M5T 2N4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4b618500f964a52090162ae3',
#     'name': 'HTO Park',
#     'location': {'address': "Queen's Quay",
#      'crossStreet': 'at Rees St.',
#      'lat': 43.63794857171933,
#      'lng': -79.38781965601113,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.63794857171933,
#        'lng': -79.38781965601113}],
#      'distance': 1783,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ["Queen's Quay (at Rees St.)",
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4ad4c05ef964a5209ff620e3',
#     'name': 'High Park',
#     'location': {'address': '1873 Bloor St. W',
#      'crossStreet': 'at Parkside Dr.',
#      'lat': 43.6464791690415,
#      'lng': -79.46342468261719,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6464791690415,
#        'lng': -79.46342468261719}],
#      'distance': 6195,
#      'postalCode': 'M6R 2Z3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1873 Bloor St. W (at Parkside Dr.)',
#       'Toronto ON M6R 2Z3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4d3a1d23325ff04db2dd1845',
#     'name': 'Residences at College Park North',
#     'location': {'address': '763 Bay St.',
#      'crossStreet': 'btwn. College St. and Gerrard St.',
#      'lat': 43.65982157793473,
#      'lng': -79.38515941616431,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65982157793473,
#        'lng': -79.38515941616431}],
#      'distance': 672,
#      'postalCode': 'M5G 2R3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['763 Bay St. (btwn. College St. and Gerrard St.)',
#       'Toronto ON M5G 2R3',
#       'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4ba5a1e2f964a5202b1839e3',
#     'name': 'Riverdale Park East',
#     'location': {'address': '550 Broadview Ave',
#      'lat': 43.66995145540962,
#      'lng': -79.35549259185791,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66995145540962,
#        'lng': -79.35549259185791}],
#      'distance': 3112,
#      'postalCode': 'M4K 2P1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['550 Broadview Ave',
#       'Toronto ON M4K 2P1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '537feaf9498e871d4bd5e016',
#     'name': 'Barbara Hall Park',
#     'location': {'address': '519 Church Street',
#      'lat': 43.666728279985655,
#      'lng': -79.38108427143717,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.666728279985655,
#        'lng': -79.38108427143717}],
#      'distance': 1504,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['519 Church Street', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4bb63b82941ad13a5e181fe3',
#     'name': 'Riverdale Park West',
#     'location': {'address': '500 Gerrard St.',
#      'crossStreet': 'at River St.',
#      'lat': 43.66604827676354,
#      'lng': -79.36094117493359,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66604827676354,
#        'lng': -79.36094117493359}],
#      'distance': 2506,
#      'postalCode': 'M5A 2H3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['500 Gerrard St. (at River St.)',
#       'Toronto ON M5A 2H3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4b9177e4f964a520d2be33e3',
#     'name': 'TTC Streetcar #403 - Victoria park',
#     'location': {'lat': 43.650735,
#      'lng': -79.386921,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650735,
#        'lng': -79.386921}],
#      'distance': 360,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fc931735',
#       'name': 'Light Rail Station',
#       'pluralName': 'Light Rail Stations',
#       'shortName': 'Light Rail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4c16a548955976b0cadea4f6',
#     'name': 'Parliament Square Park',
#     'location': {'address': '44 Parliament Street',
#      'lat': 43.65026388338689,
#      'lng': -79.36219509081177,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65026388338689,
#        'lng': -79.36219509081177}],
#      'distance': 2056,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['44 Parliament Street', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4b9c2ef4f964a520785236e3',
#     'name': 'Stanley Park',
#     'location': {'address': 'King Street West',
#      'crossStreet': 'Walnut',
#      'lat': 43.64239542050481,
#      'lng': -79.40932989120483,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64239542050481,
#        'lng': -79.40932989120483}],
#      'distance': 2198,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['King Street West (Walnut)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4b23bce0f964a520ce5824e3',
#     'name': 'Cawthra Square Dog Park',
#     'location': {'address': '519 Church St.',
#      'crossStreet': 'Wellesley',
#      'lat': 43.66658331158984,
#      'lng': -79.3800401687622,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66658331158984,
#        'lng': -79.3800401687622}],
#      'distance': 1518,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['519 Church St. (Wellesley)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e5941735',
#       'name': 'Dog Run',
#       'pluralName': 'Dog Runs',
#       'shortName': 'Dog Run',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4b9333f1f964a520fa3a34e3',
#     'name': 'Coronation Park',
#     'location': {'address': '711 Lake Shore Blvd. W',
#      'crossStreet': 'at Strachan Ave.',
#      'lat': 43.63455322391303,
#      'lng': -79.40540313720703,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.63455322391303,
#        'lng': -79.40540313720703}],
#      'distance': 2610,
#      'postalCode': 'M5V 3T7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['711 Lake Shore Blvd. W (at Strachan Ave.)',
#       'Toronto ON M5V 3T7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4c34e9f7a0ced13a96fb186e',
#     'name': 'Stanley Park (Dog Park)',
#     'location': {'address': 'King Street West',
#      'crossStreet': 'Shaw Street',
#      'lat': 43.64166802703168,
#      'lng': -79.40926920430412,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64166802703168,
#        'lng': -79.40926920430412}],
#      'distance': 2243,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['King Street West (Shaw Street)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e5941735',
#       'name': 'Dog Run',
#       'pluralName': 'Dog Runs',
#       'shortName': 'Dog Run',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4bdde5056198c9b61a1c12ff',
#     'name': 'Canoe Landing Park',
#     'location': {'address': '50 Fort York Blvd',
#      'crossStreet': 'at Dan Leckie Way',
#      'lat': 43.63876173785461,
#      'lng': -79.39706683158875,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.63876173785461,
#        'lng': -79.39706683158875}],
#      'distance': 1869,
#      'postalCode': 'M5V 3Z1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['50 Fort York Blvd (at Dan Leckie Way)',
#       'Toronto ON M5V 3Z1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '59f1fde348b04e1a8368f4f4',
#     'name': 'Physiomed College Park',
#     'location': {'address': '382 Yonge St',
#      'lat': 43.6585279,
#      'lng': -79.3821688,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6585279,
#        'lng': -79.3821688}],
#      'distance': 650,
#      'postalCode': 'M5B 1S8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['382 Yonge St', 'Toronto ON M5B 1S8', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4bb606111344b71388da9c04',
#     'name': 'Winchester Park',
#     'location': {'address': '530 Ontario Street',
#      'crossStreet': 'Ontario & Carlton',
#      'lat': 43.66623107575282,
#      'lng': -79.3716312803108,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66623107575282,
#        'lng': -79.3716312803108}],
#      'distance': 1854,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['530 Ontario Street (Ontario & Carlton)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e7941735',
#       'name': 'Playground',
#       'pluralName': 'Playgrounds',
#       'shortName': 'Playground',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4ca32b95a73cb60cc61f1678',
#     'name': 'Toothworks - College Park Dental',
#     'location': {'address': '444 Yonge St, Unit M16',
#      'crossStreet': 'in College Park',
#      'lat': 43.66000931730009,
#      'lng': -79.38390494519587,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66000931730009,
#        'lng': -79.38390494519587}],
#      'distance': 723,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['444 Yonge St, Unit M16 (in College Park)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4b68ed27f964a52086932be3',
#     'name': 'College Park',
#     'location': {'address': '444 Yonge St',
#      'crossStreet': 'at College St',
#      'lat': 43.66123664500852,
#      'lng': -79.38360253789236,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66123664500852,
#        'lng': -79.38360253789236}],
#      'distance': 860,
#      'postalCode': 'M5B 2H4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['444 Yonge St (at College St)',
#       'Toronto ON M5B 2H4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fd941735',
#       'name': 'Shopping Mall',
#       'pluralName': 'Shopping Malls',
#       'shortName': 'Mall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4b642db1f964a520b7a22ae3',
#     'name': 'Roundhouse Park',
#     'location': {'address': '255 Bremner Blvd.',
#      'crossStreet': 'at Lower Simcoe St.',
#      'lat': 43.64174513889102,
#      'lng': -79.38427882922346,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64174513889102,
#        'lng': -79.38427882922346}],
#      'distance': 1380,
#      'postalCode': 'M5V 3M9',
#      'cc': 'CA',
#      'neighborhood': 'Entertainment District',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['255 Bremner Blvd. (at Lower Simcoe St.)',
#       'Toronto ON M5V 3M9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4ae04bcaf964a520857e21e3',
#     'name': 'GoodLife Fitness Toronto Bloor Park',
#     'location': {'address': '8 Park Rd',
#      'crossStreet': 'at Bloor St. E.',
#      'lat': 43.67139808558312,
#      'lng': -79.3844083017028,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.67139808558312,
#        'lng': -79.3844083017028}],
#      'distance': 1953,
#      'postalCode': 'M4W 3G8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['8 Park Rd (at Bloor St. E.)',
#       'Toronto ON M4W 3G8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False},
#    {'id': '4b17084cf964a52038c123e3',
#     'name': 'Victoria Park Subway Station',
#     'location': {'address': '777 Victoria Park Ave',
#      'crossStreet': 'at Danforth',
#      'lat': 43.69488264493771,
#      'lng': -79.28873509168625,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.69488264493771,
#        'lng': -79.28873509168625}],
#      'distance': 9143,
#      'postalCode': 'M4B 2E2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['777 Victoria Park Ave (at Danforth)',
#       'Toronto ON M4B 2E2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fd931735',
#       'name': 'Metro Station',
#       'pluralName': 'Metro Stations',
#       'shortName': 'Metro',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562500786',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Finding relevent data from the json file and assigning to the venues

# %%
venues = park_results['response']['venues']

# tranform venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 3  [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
# 4  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
#
#                          id    location.address location.cc location.city  \
# 0  4b170e47f964a5208cc123e3  691 University Ave          CA       Toronto
# 1  4b54deadf964a520a3d027e3                 NaN          CA       Toronto
# 2  4ad4c05ef964a520bdf620e3  1053 Dundas St. W.          CA       Toronto
# 3  4ad80fcef964a520a61021e3       280 Simcoe St          CA       Toronto
# 4  4bb3c91a2397b7134d9f38b3         Spadina Ave          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada        at College St                716
# 1           Canada                  NaN                423
# 2           Canada    at Gore Vale Ave.               2271
# 3           Canada   Dundas Street West                282
# 4           Canada   at Wellington St W               1223
#
#                            location.formattedAddress  \
# 0  [691 University Ave (at College St), Toronto O...
# 1  [btwn College, University, Queen & Spadina, To...
# 2  [1053 Dundas St. W. (at Gore Vale Ave.), Toron...
# 3  [280 Simcoe St (Dundas Street West), Toronto O...
# 4  [Spadina Ave (at Wellington St W), Toronto ON,...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...     43.660006
# 1  [{'label': 'display', 'lat': 43.65248755299856...     43.652488
# 2  [{'label': 'display', 'lat': 43.64707192840234...     43.647072
# 3  [{'label': 'display', 'lat': 43.65544241747622...     43.655442
# 4  [{'label': 'display', 'lat': 43.64422227794523...     43.644222
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.390272                   NaN             M5G 2P1             ON
# 1    -79.392053                   NaN                 NaN             ON
# 2    -79.413756                   NaN             M5H 2N2             ON
# 3    -79.390056                   NaN             M5T 2Y5             ON
# 4    -79.394230                   NaN                 NaN             ON
#
#                           name    referralId venuePage.id
# 0  Queen's Park Subway Station  v-1562500786          NaN
# 1                  Grange Park  v-1562500786          NaN
# 2       Trinity Bellwoods Park  v-1562500786          NaN
# 3                One Park Lane  v-1562500786          NaN
# 4         Clarence Square Park  v-1562500786          NaN

# %% [markdown]
# #### Cleaning the park_dataframe and keeping all the necessary data

# %%
# Keeping only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                           name                                categories  \
# 0  Queen's Park Subway Station                             Metro Station
# 1                  Grange Park                                      Park
# 2       Trinity Bellwoods Park                                      Park
# 3                One Park Lane  Residential Building (Apartment / Condo)
# 4         Clarence Square Park                                      Park
#
#               address  cc     city country         crossStreet  distance  \
# 0  691 University Ave  CA  Toronto  Canada       at College St       716
# 1                 NaN  CA  Toronto  Canada                 NaN       423
# 2  1053 Dundas St. W.  CA  Toronto  Canada   at Gore Vale Ave.      2271
# 3       280 Simcoe St  CA  Toronto  Canada  Dundas Street West       282
# 4         Spadina Ave  CA  Toronto  Canada  at Wellington St W      1223
#
#                                     formattedAddress  \
# 0  [691 University Ave (at College St), Toronto O...
# 1  [btwn College, University, Queen & Spadina, To...
# 2  [1053 Dundas St. W. (at Gore Vale Ave.), Toron...
# 3  [280 Simcoe St (Dundas Street West), Toronto O...
# 4  [Spadina Ave (at Wellington St W), Toronto ON,...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...  43.660006 -79.390272
# 1  [{'label': 'display', 'lat': 43.65248755299856...  43.652488 -79.392053
# 2  [{'label': 'display', 'lat': 43.64707192840234...  43.647072 -79.413756
# 3  [{'label': 'display', 'lat': 43.65544241747622...  43.655442 -79.390056
# 4  [{'label': 'display', 'lat': 43.64422227794523...  43.644222 -79.394230
#
#   neighborhood postalCode state                        id
# 0          NaN    M5G 2P1    ON  4b170e47f964a5208cc123e3
# 1          NaN        NaN    ON  4b54deadf964a520a3d027e3
# 2          NaN    M5H 2N2    ON  4ad4c05ef964a520bdf620e3
# 3          NaN    M5T 2Y5    ON  4ad80fcef964a520a61021e3
# 4          NaN        NaN    ON  4bb3c91a2397b7134d9f38b3

# %% [markdown]
# #### Deleting all the unncessary columns

# %%
# delete unnecessary columns
clean_park_dataframe_2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe_2
# Out:
#                                    name  \
# 0           Queen's Park Subway Station
# 1                           Grange Park
# 2                Trinity Bellwoods Park
# 3                         One Park Lane
# 4                  Clarence Square Park
# 5         Crunch Fitness - College Park
# 6                           Berczy Park
# 7     St. Andrews Playground / Dog Park
# 8                          Queen's Park
# 9                  Bellevue Square Park
# 10                             HTO Park
# 11                            High Park
# 12     Residences at College Park North
# 13                  Riverdale Park East
# 14                    Barbara Hall Park
# 15                  Riverdale Park West
# 16   TTC Streetcar #403 - Victoria park
# 17               Parliament Square Park
# 18                         Stanley Park
# 19              Cawthra Square Dog Park
# 20                      Coronation Park
# 21              Stanley Park (Dog Park)
# 22                   Canoe Landing Park
# 23               Physiomed College Park
# 24                      Winchester Park
# 25     Toothworks - College Park Dental
# 26                         College Park
# 27                      Roundhouse Park
# 28  GoodLife Fitness Toronto Bloor Park
# 29         Victoria Park Subway Station
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 1                                       Park                           NaN
# 2                                       Park            1053 Dundas St. W.
# 3   Residential Building (Apartment / Condo)                 280 Simcoe St
# 4                                       Park                   Spadina Ave
# 5                       Gym / Fitness Center              382 Yonge Street
# 6                                       Park        35 Wellington St. East
# 7                                       Park      450 Adelaide Street West
# 8                                       Park               University Ave.
# 9                                       Park  btwn Bellevue & Augusta Ave.
# 10                                      Park                  Queen's Quay
# 11                                      Park              1873 Bloor St. W
# 12  Residential Building (Apartment / Condo)                   763 Bay St.
# 13                                      Park             550 Broadview Ave
# 14                                      Park             519 Church Street
# 15                                      Park               500 Gerrard St.
# 16                        Light Rail Station                           NaN
# 17                                      Park          44 Parliament Street
# 18                                      Park              King Street West
# 19                                   Dog Run                519 Church St.
# 20                                      Park        711 Lake Shore Blvd. W
# 21                                   Dog Run              King Street West
# 22                                      Park             50 Fort York Blvd
# 23                            Medical Center                  382 Yonge St
# 24                                Playground            530 Ontario Street
# 25                          Dentist's Office        444 Yonge St, Unit M16
# 26                             Shopping Mall                  444 Yonge St
# 27                                      Park             255 Bremner Blvd.
# 28                                       Gym                     8 Park Rd
# 29                             Metro Station         777 Victoria Park Ave
#
#           lat        lng            neighborhood postalCode state
# 0   43.660006 -79.390272                     NaN    M5G 2P1    ON
# 1   43.652488 -79.392053                     NaN        NaN    ON
# 2   43.647072 -79.413756                     NaN    M5H 2N2    ON
# 3   43.655442 -79.390056                     NaN    M5T 2Y5    ON
# 4   43.644222 -79.394230                     NaN        NaN    ON
# 5   43.659263 -79.382632                     NaN    M5G 1S8    ON
# 6   43.648048 -79.375172                     NaN        NaN    ON
# 7   43.647388 -79.398752                     NaN        NaN    ON
# 8   43.663946 -79.392180                     NaN    M5R 2E8    ON
# 9   43.653610 -79.402199                     NaN    M5T 2N4    ON
# 10  43.637949 -79.387820                     NaN        NaN    ON
# 11  43.646479 -79.463425                     NaN    M6R 2Z3    ON
# 12  43.659822 -79.385159                     NaN    M5G 2R3    ON
# 13  43.669951 -79.355493                     NaN    M4K 2P1    ON
# 14  43.666728 -79.381084                     NaN        NaN    ON
# 15  43.666048 -79.360941                     NaN    M5A 2H3    ON
# 16  43.650735 -79.386921                     NaN        NaN    ON
# 17  43.650264 -79.362195                     NaN        NaN    ON
# 18  43.642395 -79.409330                     NaN        NaN    ON
# 19  43.666583 -79.380040                     NaN        NaN    ON
# 20  43.634553 -79.405403                     NaN    M5V 3T7    ON
# 21  43.641668 -79.409269                     NaN        NaN    ON
# 22  43.638762 -79.397067                     NaN    M5V 3Z1    ON
# 23  43.658528 -79.382169                     NaN    M5B 1S8    ON
# 24  43.666231 -79.371631                     NaN        NaN    ON
# 25  43.660009 -79.383905                     NaN        NaN    ON
# 26  43.661237 -79.383603                     NaN    M5B 2H4    ON
# 27  43.641745 -79.384279  Entertainment District    M5V 3M9    ON
# 28  43.671398 -79.384408                     NaN    M4W 3G8    ON
# 29  43.694883 -79.288735                     NaN    M4B 2E2    ON

# %% [markdown]
# #### Deleting Rows with not assigned values

# %%
# delete rows with none values
clean_park_dataframe_3 = clean_park_dataframe_2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe_3
# Out:
#                name categories            address        lat        lng  \
# 27  Roundhouse Park       Park  255 Bremner Blvd.  43.641745 -79.384279
#
#               neighborhood postalCode state
# 27  Entertainment District    M5V 3M9    ON

# %% [markdown]
# #### Now after parks it's time for restaurants !!

# %%
# search for Restaurants
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4K3D2W4JJJU32CN2CS0GJCSDQR2UFSRAC0FKSEB0IKSE4QSA&client_secret=JGHHEXLTN1UNXP14FV3TV3E2ZLZI31ZWNTU0YCJ5WOQSILN5&ll=43.653963,-79.387207&v=20180604&query=Restaurant&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
Rest_results = requests.get(url).json()

# %% [markdown]
# #### Assigning relevent values to the venues

# %%
# assign relevant part of JSON to venues
venues = Rest_results['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe_1 = json_normalize(venues)
Restaurant_dataframe_1.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 1  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 2  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...    False
# 3  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...    False
# 4  [{'id': '4bf58dd8d48988d123941735', 'name': 'W...    False
#
#                          id     location.address location.cc location.city  \
# 0  4ad4c05ff964a52048f720e3  110 Chestnut Street          CA       Toronto
# 1  4b223f5af964a520ba4424e3        225 Frnt St W          CA       Toronto
# 2  4ad4c060f964a5207ff720e3     323 Spadina Ave.          CA       Toronto
# 3  4b072e9df964a52009f922e3     280 Spadina Ave.          CA       Toronto
# 4  4ad4c05cf964a520dff520e3       301 Front St W          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada                  NaN                145
# 1           Canada                  NaN               1039
# 2           Canada        at D'Arcy St.                922
# 3           Canada     at Dundas St. W.                892
# 4           Canada      301 Front St. W               1271
#
#                            location.formattedAddress  \
# 0  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1        [225 Frnt St W, Toronto ON M5V 2X3, Canada]
# 2  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 3  [280 Spadina Ave. (at Dundas St. W.), Toronto ...
# 4  [301 Front St W (301 Front St. W), Toronto ON ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...     43.654884
# 1  [{'label': 'display', 'lat': 43.64474919591934...     43.644749
# 2  [{'label': 'display', 'lat': 43.65431754076345...     43.654318
# 3  [{'label': 'display', 'lat': 43.65278331265585...     43.652783
# 4  [{'label': 'display', 'lat': 43.64253731714456...     43.642537
#
#    location.lng   location.neighborhood location.postalCode location.state  \
# 0    -79.385931                     NaN             M5G 1R3             ON
# 1    -79.385113  Entertainment District             M5V 2X3             ON
# 2    -79.398650       Kensington Market             M5T 2E9             ON
# 3    -79.398174                     NaN                 NaN             ON
# 4    -79.387042                     NaN             M5V 2T6             ON
#
#                                  name    referralId venuePage.id
# 0     Hemispheres Restaurant & Bistro  v-1562501013          NaN
# 1              Azure Restaurant & Bar  v-1562501013    136175835
# 2              Rol San Restaurant 龍笙棧  v-1562501013          NaN
# 3  Sky Dragon Chinese Restaurant 龍翔酒樓  v-1562501013          NaN
# 4                      360 Restaurant  v-1562501013          NaN

# %% [markdown]
# #### Cleaning the Restaurant_dataframe_1

# %%
# keep only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe_1.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe_1.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                                  name           categories  \
# 0     Hemispheres Restaurant & Bistro  American Restaurant
# 1              Azure Restaurant & Bar           Restaurant
# 2              Rol San Restaurant 龍笙棧   Dim Sum Restaurant
# 3  Sky Dragon Chinese Restaurant 龍翔酒樓   Dim Sum Restaurant
# 4                      360 Restaurant             Wine Bar
#
#                address  cc     city country       crossStreet  distance  \
# 0  110 Chestnut Street  CA  Toronto  Canada               NaN       145
# 1        225 Frnt St W  CA  Toronto  Canada               NaN      1039
# 2     323 Spadina Ave.  CA  Toronto  Canada     at D'Arcy St.       922
# 3     280 Spadina Ave.  CA  Toronto  Canada  at Dundas St. W.       892
# 4       301 Front St W  CA  Toronto  Canada   301 Front St. W      1271
#
#                                     formattedAddress  \
# 0  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1        [225 Frnt St W, Toronto ON M5V 2X3, Canada]
# 2  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 3  [280 Spadina Ave. (at Dundas St. W.), Toronto ...
# 4  [301 Front St W (301 Front St. W), Toronto ON ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...  43.654884 -79.385931
# 1  [{'label': 'display', 'lat': 43.64474919591934...  43.644749 -79.385113
# 2  [{'label': 'display', 'lat': 43.65431754076345...  43.654318 -79.398650
# 3  [{'label': 'display', 'lat': 43.65278331265585...  43.652783 -79.398174
# 4  [{'label': 'display', 'lat': 43.64253731714456...  43.642537 -79.387042
#
#              neighborhood postalCode state                        id
# 0                     NaN    M5G 1R3    ON  4ad4c05ff964a52048f720e3
# 1  Entertainment District    M5V 2X3    ON  4b223f5af964a520ba4424e3
# 2       Kensington Market    M5T 2E9    ON  4ad4c060f964a5207ff720e3
# 3                     NaN        NaN    ON  4b072e9df964a52009f922e3
# 4                     NaN    M5V 2T6    ON  4ad4c05cf964a520dff520e3

# %% [markdown]
# #### Deleting unnecessary columns

# %%
# delete unnecessary columns
clean_Restaurant_dataframe_2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Restaurant_dataframe_2
# Out:
#                                               name               categories  \
# 0                  Hemispheres Restaurant & Bistro      American Restaurant
# 1                           Azure Restaurant & Bar               Restaurant
# 2                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 3               Sky Dragon Chinese Restaurant 龍翔酒樓       Dim Sum Restaurant
# 4                                   360 Restaurant                 Wine Bar
# 5                            Victoria's Restaurant               Restaurant
# 6                   The Hot House Restaurant & Bar      American Restaurant
# 7                   Goldstone Noodle Restaurant 金石             Noodle House
# 8                          Victor Restaurant & Bar                      Bar
# 9                    Green Tea Restaurant Downtown       Chinese Restaurant
# 10                         Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 11                    Aroma Fine Indian Restaurant        Indian Restaurant
# 12                        New Sky Restaurant 小沙田食家       Chinese Restaurant
# 13         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 14  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 15                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 16                      Matisse Restaurant And Bar               Restaurant
# 17                           ONE Restaurant/Lounge  New American Restaurant
# 18                                Union Restaurant  New American Restaurant
# 19                               Studio Restaurant           Breakfast Spot
# 20              North-East Chinese Restaurant 華北美食       Chinese Restaurant
# 21             Richtree Natural Market Restaurants               Restaurant
# 22                           Sightlines Restaurant      American Restaurant
# 23                          The Senator Restaurant                    Diner
# 24                  Insomnia Restaurant and Lounge               Restaurant
# 25                         The Lakeview Restaurant                    Diner
# 26                               Tundra Restaurant               Restaurant
# 27               El Rancho Restaurant & Night Club                Nightclub
# 28                 Bright Pearl Seafood Restaurant       Chinese Restaurant
# 29                        Ka Chi Korean Restaurant        Korean Restaurant
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                     225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 2                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 3                  280 Spadina Ave.  43.652783 -79.398174        NaN    ON
# 4                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 5               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 6                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 7                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 8                  30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 9   261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 10                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 11                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 12                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 13                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 14            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 15                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 16                     90 Bloor St.  43.670574 -79.384856    M4W 1A7    ON
# 17                116 Yorkville Ave  43.670809 -79.393272        NaN    ON
# 18                72 Ossington Ave.  43.645860 -79.419532        NaN    ON
# 19                   389 Church St.  43.661500 -79.379319        M5B    ON
# 20                   476 Dundas St.  43.653185 -79.396677        NaN    ON
# 21                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 22                    Rogers Centre  43.641635 -79.389365        NaN    ON
# 23              249 Victoria Street  43.655641 -79.379199    M5B 1T8    ON
# 24                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 25                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 26         145 Richmond Street West  43.650010 -79.385608    M5H 2L2    ON
# 27                  430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 28           346-348 Spadina Avenue  43.654219 -79.399125    M5T 2G2    ON
# 29                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON

# %% [markdown]
# #### Deleting rows with not assigned values

# %%
# delete rows with none values
df_Restaurant = clean_Restaurant_dataframe_2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                               name            categories  \
# 0                  Hemispheres Restaurant & Bistro   American Restaurant
# 1                           Azure Restaurant & Bar            Restaurant
# 2                           Rol San Restaurant 龍笙棧    Dim Sum Restaurant
# 4                                   360 Restaurant              Wine Bar
# 5                            Victoria's Restaurant            Restaurant
# 6                   The Hot House Restaurant & Bar   American Restaurant
# 7                   Goldstone Noodle Restaurant 金石          Noodle House
# 8                          Victor Restaurant & Bar                   Bar
# 9                    Green Tea Restaurant Downtown    Chinese Restaurant
# 10                         Swatow Restaurant 汕頭小食家    Chinese Restaurant
# 11                    Aroma Fine Indian Restaurant     Indian Restaurant
# 12                        New Sky Restaurant 小沙田食家    Chinese Restaurant
# 13         Tasty's Caribbean Restaurant & Catering  Caribbean Restaurant
# 14  Sassafraz | Cafe | Restaurant | Private Events           Event Space
# 15                   Hong Shing Chinese Restaurant    Chinese Restaurant
# 16                      Matisse Restaurant And Bar            Restaurant
# 19                               Studio Restaurant        Breakfast Spot
# 21             Richtree Natural Market Restaurants            Restaurant
# 23                          The Senator Restaurant                 Diner
# 24                  Insomnia Restaurant and Lounge            Restaurant
# 25                         The Lakeview Restaurant                 Diner
# 26                               Tundra Restaurant            Restaurant
# 27               El Rancho Restaurant & Night Club             Nightclub
# 28                 Bright Pearl Seafood Restaurant    Chinese Restaurant
# 29                        Ka Chi Korean Restaurant     Korean Restaurant
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                     225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 2                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 4                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 5               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 6                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 7                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 8                  30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 9   261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 10                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 11                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 12                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 13                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 14            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 15                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 16                     90 Bloor St.  43.670574 -79.384856    M4W 1A7    ON
# 19                   389 Church St.  43.661500 -79.379319        M5B    ON
# 21                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 23              249 Victoria Street  43.655641 -79.379199    M5B 1T8    ON
# 24                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 25                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 26         145 Richmond Street West  43.650010 -79.385608    M5H 2L2    ON
# 27                  430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 28           346-348 Spadina Avenue  43.654219 -79.399125    M5T 2G2    ON
# 29                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON

# %% [markdown]
# #### Searching for cafes nearby !!

# %%
search_query = 'Cafeteria'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4K3D2W4JJJU32CN2CS0GJCSDQR2UFSRAC0FKSEB0IKSE4QSA&client_secret=JGHHEXLTN1UNXP14FV3TV3E2ZLZI31ZWNTU0YCJ5WOQSILN5&ll=43.653963,-79.387207&v=20180604&query=Cafeteria&radius=10000&limit=30'

# %%
cafe_results = requests.get(url).json()

# %% [markdown]
# #### Assigning relevent part to vemues and transforming the data

# %%
venues = cafe_results['response']['venues']

# tranform venues into a dataframe
cafe_dataframe = json_normalize(venues)
cafe_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...    False
# 2  [{'id': '4bf58dd8d48988d1a1941735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d1c1941735', 'name': 'M...    False
# 4  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...    False
#
#                          id                           location.address  \
# 0  4f9165bde4b04fef0087e4e2  The Hospital for Sick Children (SickKids)
# 1  528e99a211d262edc3708a6f                            388 Spadina Ave
# 2  4ec2b68a8231a83de8c45191                             100 McCaul St.
# 3  56b2c90a498e9f0e73d6bed6                             974 College St
# 4  53bd6dfe498e6c1d3bc9333e                                        NaN
#
#   location.cc location.city location.country location.crossStreet  \
# 0          CA       Toronto           Canada                  NaN
# 1          CA       Toronto           Canada         at Nassau St
# 2          CA       Toronto           Canada         Second Floor
# 3          CA       Toronto           Canada                  NaN
# 4          CA       Toronto           Canada                  NaN
#
#    location.distance                          location.formattedAddress  \
# 0                372  [The Hospital for Sick Children (SickKids), To...
# 1                977  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2                389  [100 McCaul St. (Second Floor), Toronto ON, Ca...
# 3               3260       [974 College St, Toronto ON M6H 1A5, Canada]
# 4                260                               [Toronto ON, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...     43.657209
# 1  [{'label': 'display', 'lat': 43.65545427446646...     43.655454
# 2  [{'label': 'display', 'lat': 43.65278016892648...     43.652780
# 3  [{'label': 'display', 'lat': 43.65341883567197...     43.653419
# 4  [{'label': 'display', 'lat': 43.655657, 'lng':...     43.655657
#
#    location.lng location.postalCode location.state  \
# 0    -79.386063                 NaN             ON
# 1    -79.399163             M5T 2G5             ON
# 2    -79.391762                 NaN             ON
# 3    -79.427678             M6H 1A5             ON
# 4    -79.389443                 NaN             ON
#
#                             name    referralId
# 0                      Cafeteria  v-1562501204
# 1              Stay Cafeteria 慢走  v-1562501204
# 2                 OCAD Cafeteria  v-1562501204
# 3                      Cafeteria  v-1562501204
# 4  Industrial Alliance Cafeteria  v-1562501204

# %% [markdown]
# #### Cleaning the cafe_dataframe

# %%
# keeping only columns that include venue name, and anything that is associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in cafe_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = cafe_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                             name            categories  \
# 0                      Cafeteria  Fast Food Restaurant
# 1              Stay Cafeteria 慢走      Asian Restaurant
# 2                 OCAD Cafeteria     College Cafeteria
# 3                      Cafeteria    Mexican Restaurant
# 4  Industrial Alliance Cafeteria             Cafeteria
#
#                                      address  cc     city country  \
# 0  The Hospital for Sick Children (SickKids)  CA  Toronto  Canada
# 1                            388 Spadina Ave  CA  Toronto  Canada
# 2                             100 McCaul St.  CA  Toronto  Canada
# 3                             974 College St  CA  Toronto  Canada
# 4                                        NaN  CA  Toronto  Canada
#
#     crossStreet  distance                                   formattedAddress  \
# 0           NaN       372  [The Hospital for Sick Children (SickKids), To...
# 1  at Nassau St       977  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2  Second Floor       389  [100 McCaul St. (Second Floor), Toronto ON, Ca...
# 3           NaN      3260       [974 College St, Toronto ON M6H 1A5, Canada]
# 4           NaN       260                               [Toronto ON, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...  43.657209 -79.386063
# 1  [{'label': 'display', 'lat': 43.65545427446646...  43.655454 -79.399163
# 2  [{'label': 'display', 'lat': 43.65278016892648...  43.652780 -79.391762
# 3  [{'label': 'display', 'lat': 43.65341883567197...  43.653419 -79.427678
# 4  [{'label': 'display', 'lat': 43.655657, 'lng':...  43.655657 -79.389443
#
#   postalCode state                        id
# 0        NaN    ON  4f9165bde4b04fef0087e4e2
# 1    M5T 2G5    ON  528e99a211d262edc3708a6f
# 2        NaN    ON  4ec2b68a8231a83de8c45191
# 3    M6H 1A5    ON  56b2c90a498e9f0e73d6bed6
# 4        NaN    ON  53bd6dfe498e6c1d3bc9333e

# %% [markdown]
# #### Deleting all the uneccessary columns

# %%
# delete unnecessary columns
clean_Cafeteria_dataframe_2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe_2
# Out:
#                                      name            categories  \
# 0                               Cafeteria  Fast Food Restaurant
# 1                       Stay Cafeteria 慢走      Asian Restaurant
# 2                          OCAD Cafeteria     College Cafeteria
# 3                               Cafeteria    Mexican Restaurant
# 4           Industrial Alliance Cafeteria             Cafeteria
# 5                         Dears Cafeteria          Dessert Shop
# 6                 Chestnut Tree Cafeteria             Cafeteria
# 7                         Sears Cafeteria            Food Court
# 8           De La Salle College Cafeteria     College Cafeteria
# 9                       Med Sci Cafeteria     College Cafeteria
# 10                  Ryerson Hub Cafeteria     College Cafeteria
# 11                     SickKids Cafeteria            Food Court
# 12              Macdonald Block Cafeteria             Cafeteria
# 13  George Brown College St. James Campus     Community College
# 14                       Rogers Cafeteria            Food Court
# 15                      Robarts Cafeteria     College Cafeteria
# 16                          OMP Cafeteria             Cafeteria
# 17                      Choices Cafeteria            Food Court
# 18    Cafeteria, Lawrence Park Collegiate           High School
# 19                       Kasala Cafeteria    African Restaurant
# 20    Cafeteria, Lawrence Park Collegiate           Event Space
# 21                             Marketeria            Restaurant
# 22               Estonian House Cafeteria                  Café
# 23                                The Hub     College Cafeteria
# 24                           CC Cafeteria     College Cafeteria
# 25                             Radio Cafe            Food Court
# 26                      Glendon Cafeteria     College Cafeteria
# 27     Lawrence Park Collegiate Cafeteria           High School
# 28                           L5 Cafeteria      Cuban Restaurant
# 29                               One Hour    Chinese Restaurant
#
#                                       address        lat        lng  \
# 0   The Hospital for Sick Children (SickKids)  43.657209 -79.386063
# 1                             388 Spadina Ave  43.655454 -79.399163
# 2                              100 McCaul St.  43.652780 -79.391762
# 3                              974 College St  43.653419 -79.427678
# 4                                         NaN  43.655657 -79.389443
# 5                                         NaN  43.654179 -79.392555
# 6                          89 Chestnut Street  43.648231 -79.384045
# 7                                       Yonge  43.656038 -79.380672
# 8                          131 Farnham Avenue  43.683003 -79.397815
# 9                                         NaN  43.660260 -79.392977
# 10                           350 Victoria St.  43.658475 -79.377653
# 11                      555 University Avenue  43.657584 -79.375652
# 12                                        NaN  43.663212 -79.388062
# 13                             51 Dockside Dr  43.644163 -79.366375
# 14                                        NaN  43.669904 -79.379748
# 15                         130 St. George St.  43.664864 -79.399766
# 16                           1 Mount Pleasant  43.669801 -79.379790
# 17                         200 Bloor Street E  43.671411 -79.381849
# 18                                        NaN  43.721732 -79.409600
# 19                                      Bloor  43.660759 -79.424018
# 20                                        NaN  43.723286 -79.412222
# 21                                30 Bond St.  43.653585 -79.378843
# 22                       958 Broadview avenue  43.681763 -79.358246
# 23                           350 Victoria St.  43.658585 -79.380622
# 24                             951 Carlaw Ave  43.684631 -79.348862
# 25                          333 Bloor st east  43.671696 -79.380617
# 26                           2275 Bayview Ave  43.727383 -79.378080
# 27                                        NaN  43.722757 -79.413734
# 28                                        NaN  43.723019 -79.345012
# 29                           435 Spadina Ave.  43.657399 -79.399649
#
#    postalCode state
# 0         NaN    ON
# 1     M5T 2G5    ON
# 2         NaN    ON
# 3     M6H 1A5    ON
# 4         NaN    ON
# 5         NaN   NaN
# 6         NaN    ON
# 7         NaN    ON
# 8     M4V 1H7    ON
# 9         NaN    ON
# 10        NaN    ON
# 11        NaN    ON
# 12        NaN   NaN
# 13    M5A 0B6    ON
# 14        NaN    ON
# 15        NaN    ON
# 16        NaN    ON
# 17        NaN    ON
# 18        NaN   NaN
# 19        NaN   NaN
# 20        NaN   NaN
# 21    M5B 1W8    ON
# 22        NaN    ON
# 23    M5B 2K3    ON
# 24        NaN    ON
# 25        NaN    ON
# 26        NaN    ON
# 27        NaN    ON
# 28        NaN   NaN
# 29    M5T 2T6    ON

# %% [markdown]
# #### Deleting rows with not assigned values

# %%
df_cafe = clean_Cafeteria_dataframe_2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_cafe
# Out:
#                                      name          categories  \
# 1                       Stay Cafeteria 慢走    Asian Restaurant
# 3                               Cafeteria  Mexican Restaurant
# 8           De La Salle College Cafeteria   College Cafeteria
# 13  George Brown College St. James Campus   Community College
# 21                             Marketeria          Restaurant
# 23                                The Hub   College Cafeteria
# 29                               One Hour  Chinese Restaurant
#
#                address        lat        lng postalCode state
# 1      388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 3       974 College St  43.653419 -79.427678    M6H 1A5    ON
# 8   131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 13      51 Dockside Dr  43.644163 -79.366375    M5A 0B6    ON
# 21         30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 23    350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 29    435 Spadina Ave.  43.657399 -79.399649    M5T 2T6    ON

# %% [markdown]
# #### Now it's time for getting the data of the shopping centres where the businessman might be interested to buy !!

# %%
search_query = 'Shopping'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4K3D2W4JJJU32CN2CS0GJCSDQR2UFSRAC0FKSEB0IKSE4QSA&client_secret=JGHHEXLTN1UNXP14FV3TV3E2ZLZI31ZWNTU0YCJ5WOQSILN5&ll=43.653963,-79.387207&v=20180604&query=Shopping&radius=1000&limit=30'

# %%
shop_results = requests.get(url).json()
shop_results
# Out:
# {'meta': {'code': 200, 'requestId': '5d21e0e89b514f7b3cfc5308'},
#  'response': {'venues': [{'id': '4ad4c062f964a520fcf720e3',
#     'name': 'Dragon City Shopping Mall 龍城',
#     'location': {'address': '280 Spadina Ave',
#      'crossStreet': 'at Dundas St W',
#      'lat': 43.65277367198862,
#      'lng': -79.39822232898479,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65277367198862,
#        'lng': -79.39822232898479}],
#      'distance': 897,
#      'postalCode': 'M5T 3A5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['280 Spadina Ave (at Dundas St W)',
#       'Toronto ON M5T 3A5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fd941735',
#       'name': 'Shopping Mall',
#       'pluralName': 'Shopping Malls',
#       'shortName': 'Mall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562501352',
#     'hasPerk': False},
#    {'id': '4ad77a12f964a520260b21e3',
#     'name': 'CF Toronto Eaton Centre',
#     'location': {'address': '220 Yonge St',
#      'crossStreet': 'btwn Queen & Dundas',
#      'lat': 43.654206473042734,
#      'lng': -79.38069937751656,
#      'distance': 524,
#      'postalCode': 'M5B 2H1',
#      'cc': 'CA',
#      'neighborhood': 'Downtown Toronto, Toronto, ON',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['220 Yonge St (btwn Queen & Dundas)',
#       'Toronto ON M5B 2H1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fd941735',
#       'name': 'Shopping Mall',
#       'pluralName': 'Shopping Malls',
#       'shortName': 'Mall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562501352',
#     'hasPerk': False},
#    {'id': '4b9e86dff964a520e6eb36e3',
#     'name': 'TD Centre Shopping Concourse',
#     'location': {'address': '66 Wellington St W',
#      'crossStreet': 'btw York & Bay St',
#      'lat': 43.64718424611984,
#      'lng': -79.38093185357147,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64718424611984,
#        'lng': -79.38093185357147}],
#      'distance': 908,
#      'postalCode': 'M5K 1A1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['66 Wellington St W (btw York & Bay St)',
#       'Toronto ON M5K 1A1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fd941735',
#       'name': 'Shopping Mall',
#       'pluralName': 'Shopping Malls',
#       'shortName': 'Mall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562501352',
#     'hasPerk': False},
#    {'id': '5840cafe06f1a34af80cc609',
#     'name': 'Saks Fifth Avenue Club - Personal Shopping',
#     'location': {'address': '176 Yonge Street',
#      'crossStreet': 'Queen Street West',
#      'lat': 43.65181,
#      'lng': -79.379192,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65181,
#        'lng': -79.379192}],
#      'distance': 688,
#      'postalCode': 'M5C 2L7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['176 Yonge Street (Queen Street West)',
#       'Toronto ON M5C 2L7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1f6941735',
#       'name': 'Department Store',
#       'pluralName': 'Department Stores',
#       'shortName': 'Department Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562501352',
#     'hasPerk': False},
#    {'id': '4b83d653f964a520d91231e3',
#     'name': 'Yellow Pages - RedFlagDeals.com',
#     'location': {'address': '461 King St. West',
#      'lat': 43.64795765580337,
#      'lng': -79.39600592454082,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64795765580337,
#        'lng': -79.39600592454082}],
#      'distance': 974,
#      'postalCode': 'M5V 1K4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['461 King St. West',
#       'Toronto ON M5V 1K4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1562501352',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Assigning relevent data to the venues

# %%
# assign relevant part of JSON to venues
venues = shop_results['response']['venues']

# tranform venues into a dataframe
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 1  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 3  [{'id': '4bf58dd8d48988d1f6941735', 'name': 'D...    False
# 4  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
#
#                          id    location.address location.cc location.city  \
# 0  4ad4c062f964a520fcf720e3     280 Spadina Ave          CA       Toronto
# 1  4ad77a12f964a520260b21e3        220 Yonge St          CA       Toronto
# 2  4b9e86dff964a520e6eb36e3  66 Wellington St W          CA       Toronto
# 3  5840cafe06f1a34af80cc609    176 Yonge Street          CA       Toronto
# 4  4b83d653f964a520d91231e3   461 King St. West          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada       at Dundas St W                897
# 1           Canada  btwn Queen & Dundas                524
# 2           Canada    btw York & Bay St                908
# 3           Canada    Queen Street West                688
# 4           Canada                  NaN                974
#
#                            location.formattedAddress  \
# 0  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2  [66 Wellington St W (btw York & Bay St), Toron...
# 3  [176 Yonge Street (Queen Street West), Toronto...
# 4    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...     43.652774
# 1                                                NaN     43.654206
# 2  [{'label': 'display', 'lat': 43.64718424611984...     43.647184
# 3  [{'label': 'display', 'lat': 43.65181, 'lng': ...     43.651810
# 4  [{'label': 'display', 'lat': 43.64795765580337...     43.647958
#
#    location.lng          location.neighborhood location.postalCode  \
# 0    -79.398222                            NaN             M5T 3A5
# 1    -79.380699  Downtown Toronto, Toronto, ON             M5B 2H1
# 2    -79.380932                            NaN             M5K 1A1
# 3    -79.379192                            NaN             M5C 2L7
# 4    -79.396006                            NaN             M5V 1K4
#
#   location.state                                        name    referralId
# 0             ON                Dragon City Shopping Mall 龍城  v-1562501352
# 1             ON                     CF Toronto Eaton Centre  v-1562501352
# 2             ON                TD Centre Shopping Concourse  v-1562501352
# 3             ON  Saks Fifth Avenue Club - Personal Shopping  v-1562501352
# 4             ON             Yellow Pages - RedFlagDeals.com  v-1562501352

# %% [markdown]
# #### Cleaning the shopping_dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1                     CF Toronto Eaton Centre     Shopping Mall
# 2                TD Centre Shopping Concourse     Shopping Mall
# 3  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 4             Yellow Pages - RedFlagDeals.com            Office
#
#               address  cc     city country          crossStreet  distance  \
# 0     280 Spadina Ave  CA  Toronto  Canada       at Dundas St W       897
# 1        220 Yonge St  CA  Toronto  Canada  btwn Queen & Dundas       524
# 2  66 Wellington St W  CA  Toronto  Canada    btw York & Bay St       908
# 3    176 Yonge Street  CA  Toronto  Canada    Queen Street West       688
# 4   461 King St. West  CA  Toronto  Canada                  NaN       974
#
#                                     formattedAddress  \
# 0  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2  [66 Wellington St W (btw York & Bay St), Toron...
# 3  [176 Yonge Street (Queen Street West), Toronto...
# 4    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...  43.652774 -79.398222
# 1                                                NaN  43.654206 -79.380699
# 2  [{'label': 'display', 'lat': 43.64718424611984...  43.647184 -79.380932
# 3  [{'label': 'display', 'lat': 43.65181, 'lng': ...  43.651810 -79.379192
# 4  [{'label': 'display', 'lat': 43.64795765580337...  43.647958 -79.396006
#
#                     neighborhood postalCode state                        id
# 0                            NaN    M5T 3A5    ON  4ad4c062f964a520fcf720e3
# 1  Downtown Toronto, Toronto, ON    M5B 2H1    ON  4ad77a12f964a520260b21e3
# 2                            NaN    M5K 1A1    ON  4b9e86dff964a520e6eb36e3
# 3                            NaN    M5C 2L7    ON  5840cafe06f1a34af80cc609
# 4                            NaN    M5V 1K4    ON  4b83d653f964a520d91231e3

# %% [markdown]
# #### Deleting all unnecessary columns

# %%
# delete unnecessary columns
clean_Shopping_dataframe_2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Shopping_dataframe_2
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1                     CF Toronto Eaton Centre     Shopping Mall
# 2                TD Centre Shopping Concourse     Shopping Mall
# 3  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 4             Yellow Pages - RedFlagDeals.com            Office
#
#               address        lat        lng postalCode state
# 0     280 Spadina Ave  43.652774 -79.398222    M5T 3A5    ON
# 1        220 Yonge St  43.654206 -79.380699    M5B 2H1    ON
# 2  66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON
# 3    176 Yonge Street  43.651810 -79.379192    M5C 2L7    ON
# 4   461 King St. West  43.647958 -79.396006    M5V 1K4    ON

# %% [markdown]
# #### Cleaning the rows whose category is not shopping mall

# %%
df_Shopping = clean_Shopping_dataframe_2[clean_Shopping_dataframe_2.categories == 'Shopping Mall']
df_Shopping
# Out:
#                            name     categories             address        lat  \
# 0  Dragon City Shopping Mall 龍城  Shopping Mall     280 Spadina Ave  43.652774
# 1       CF Toronto Eaton Centre  Shopping Mall        220 Yonge St  43.654206
# 2  TD Centre Shopping Concourse  Shopping Mall  66 Wellington St W  43.647184
#
#          lng postalCode state
# 0 -79.398222    M5T 3A5    ON
# 1 -79.380699    M5B 2H1    ON
# 2 -79.380932    M5K 1A1    ON

# %% [markdown]
# ## Now let's visualize all these through maps and cluster the data together so that the businessman can have a better insight of the area where he want to invest his money on¶

# %% [markdown]
# ### First of all generating maps for all the 6 fields will not be very much convincing so let's divide it in two parts the first map is for shopping malls,cafes and hotels

# %% [markdown]
# #### Let's create the dataframe for the three and merge it

# %%
# create dataframe of hotels, shopping stores and Cafeteria
hotel_neighbourhood_df = pd.concat([df_hotel, df_cafe, df_Shopping], ignore_index=True)
hotel_neighbourhood_df
# Out:
#                                      name          categories  \
# 0           Sheraton Centre Toronto Hotel               Hotel
# 1                          Grand Ballroom         Event Space
# 2                       Stay Cafeteria 慢走    Asian Restaurant
# 3                               Cafeteria  Mexican Restaurant
# 4           De La Salle College Cafeteria   College Cafeteria
# 5   George Brown College St. James Campus   Community College
# 6                              Marketeria          Restaurant
# 7                                 The Hub   College Cafeteria
# 8                                One Hour  Chinese Restaurant
# 9            Dragon City Shopping Mall 龍城       Shopping Mall
# 10                CF Toronto Eaton Centre       Shopping Mall
# 11           TD Centre Shopping Concourse       Shopping Mall
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651129 -79.383829    M5H 2M9    ON
# 1         123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON
# 2         388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 3          974 College St  43.653419 -79.427678    M6H 1A5    ON
# 4      131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 5          51 Dockside Dr  43.644163 -79.366375    M5A 0B6    ON
# 6             30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 7        350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 8        435 Spadina Ave.  43.657399 -79.399649    M5T 2T6    ON
# 9         280 Spadina Ave  43.652774 -79.398222    M5T 3A5    ON
# 10           220 Yonge St  43.654206 -79.380699    M5B 2H1    ON
# 11     66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON

# %% [markdown]
# #### Generating map now !!

# %%
# Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria 
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Now visualizing park,cafes and restaurants !!

# %%
# create dataframe of Park, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_park,df_Restaurant, df_cafe,], ignore_index=True,sort=False)
park_neighbourhood_df
# Out:
#                                               name            categories  \
# 0                  Hemispheres Restaurant & Bistro   American Restaurant
# 1                           Azure Restaurant & Bar            Restaurant
# 2                           Rol San Restaurant 龍笙棧    Dim Sum Restaurant
# 3                                   360 Restaurant              Wine Bar
# 4                            Victoria's Restaurant            Restaurant
# 5                   The Hot House Restaurant & Bar   American Restaurant
# 6                   Goldstone Noodle Restaurant 金石          Noodle House
# 7                          Victor Restaurant & Bar                   Bar
# 8                    Green Tea Restaurant Downtown    Chinese Restaurant
# 9                          Swatow Restaurant 汕頭小食家    Chinese Restaurant
# 10                    Aroma Fine Indian Restaurant     Indian Restaurant
# 11                        New Sky Restaurant 小沙田食家    Chinese Restaurant
# 12         Tasty's Caribbean Restaurant & Catering  Caribbean Restaurant
# 13  Sassafraz | Cafe | Restaurant | Private Events           Event Space
# 14                   Hong Shing Chinese Restaurant    Chinese Restaurant
# 15                      Matisse Restaurant And Bar            Restaurant
# 16                               Studio Restaurant        Breakfast Spot
# 17             Richtree Natural Market Restaurants            Restaurant
# 18                          The Senator Restaurant                 Diner
# 19                  Insomnia Restaurant and Lounge            Restaurant
# 20                         The Lakeview Restaurant                 Diner
# 21                               Tundra Restaurant            Restaurant
# 22               El Rancho Restaurant & Night Club             Nightclub
# 23                 Bright Pearl Seafood Restaurant    Chinese Restaurant
# 24                        Ka Chi Korean Restaurant     Korean Restaurant
# 25                               Stay Cafeteria 慢走      Asian Restaurant
# 26                                       Cafeteria    Mexican Restaurant
# 27                   De La Salle College Cafeteria     College Cafeteria
# 28           George Brown College St. James Campus     Community College
# 29                                      Marketeria            Restaurant
# 30                                         The Hub     College Cafeteria
# 31                                        One Hour    Chinese Restaurant
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                     225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 2                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 3                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 4               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 5                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 6                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 7                  30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 8   261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 9                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 10                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 11                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 12                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 13            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 14                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 15                     90 Bloor St.  43.670574 -79.384856    M4W 1A7    ON
# 16                   389 Church St.  43.661500 -79.379319        M5B    ON
# 17                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 18              249 Victoria Street  43.655641 -79.379199    M5B 1T8    ON
# 19                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 20                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 21         145 Richmond Street West  43.650010 -79.385608    M5H 2L2    ON
# 22                  430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 23           346-348 Spadina Avenue  43.654219 -79.399125    M5T 2G2    ON
# 24                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 25                  388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 26                   974 College St  43.653419 -79.427678    M6H 1A5    ON
# 27               131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 28                   51 Dockside Dr  43.644163 -79.366375    M5A 0B6    ON
# 29                      30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 30                 350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 31                 435 Spadina Ave.  43.657399 -79.399649    M5T 2T6    ON

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
mmap = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(mmap)  
    
mmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## So finally we are done with our capstone project and the busniessman is finally satisfied by data he has been provided by our team and is really happy and finds out that investing in restaurants will be very beneficial and he is also happy that he got it near the a landscape veiw.
